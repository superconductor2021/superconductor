# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
from pylab import *
mpl.rcParams['font.sans-serif'] = ['SimHei']

# %%
path = 'F://Code//jupyter_notebook//超导体//Dataset/有机.xlsx'
df = pd.read_excel(path, engine='openpyxl').drop(['fig1', 'fig2'], axis = 1)

df
# Out:
#       num                          fullname     tc  pcrit   pmax         refno
# 0       1         kappa-(BEDT-TTF)2Cu(NCS)2   9.50  0.000    NaN    PR05403760
# 1       2     kappa-(BEDT-TTF)2Cu[N(CN)2]Cl  12.60  0.030  0.030    JPS0652987
# 2       3     kappa-(BEDT-TTF)2Cu[N(CN)2]Cl  13.00  0.044  0.045    JPS0652987
# 3       4     kappa-(BEDT-TTF)2Cu[N(CN)2]Br  11.50  0.000    NaN    PR05705610
# 4       5      alpha-(BEDT-TTF)2NH4Hg(SCN)4   0.95  0.000    NaN    PR05703623
# ..    ...                               ...    ...    ...    ...           ...
# 557   700  (beta)''-(BEDT-TTF)2SF5CH2CF2SO3   5.20    NaN    NaN  PRB100014515
# 558  1001      alpha-(BEDT-TTF)2NH4Hg(SCN)4   0.95    NaN    NaN    PR05703623
# 559  1002     kappa-(BEDT-TTF)2Cu[N(CN)2]Cl  12.60  0.019    NaN    JPS0652987
# 560  1003     kappa-(BEDT-TTF)2Cu[N(CN)2]Cl  13.00  0.034    NaN    JPS0652987
# 561  1004     kappa-(BEDT-TTF)2Cu[N(CN)2]Br  11.50    NaN    NaN    PR05705610
#
# [562 rows x 6 columns]

# %%
df.to_csv('有机.csv')
